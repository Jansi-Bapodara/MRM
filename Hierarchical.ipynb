# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")
print(df.head())
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
# Separate categorical and numerical data
categorical_col = df.iloc[:, 0]
numerical_cols = df.iloc[:, 1:]

# One-hot encode the categorical column
categorical_encoded = pd.get_dummies(categorical_col)

# %%
# Combine encoded categorical + numerical features
X = pd.concat([categorical_encoded, numerical_cols], axis=1)

# Convert to NumPy array
X = X.values.astype(float)
print(X)
# Out:
# [[1.00e+00 0.00e+00 0.00e+00 ... 5.62e+01 5.82e+00 5.53e+02]
#  [0.00e+00 1.00e+00 0.00e+00 ... 7.63e+01 1.65e+00 4.09e+03]
#  [0.00e+00 0.00e+00 1.00e+00 ... 7.65e+01 2.89e+00 4.46e+03]
#  ...
#  [0.00e+00 0.00e+00 0.00e+00 ... 7.31e+01 1.95e+00 1.31e+03]
#  [0.00e+00 0.00e+00 0.00e+00 ... 6.75e+01 4.67e+00 1.31e+03]
#  [0.00e+00 0.00e+00 0.00e+00 ... 5.20e+01 5.40e+00 1.46e+03]]

# %%
def euclidean_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

# %%
def compute_distance_matrix(X):
    n = X.shape[0]
    dist_matrix = np.zeros((n, n))
    
    for i in range(n):
        for j in range(i + 1, n):
            dist = euclidean_distance(X[i], X[j])
            dist_matrix[i, j] = dist
            dist_matrix[j, i] = dist
            
    return dist_matrix

# %%
def average_linkage(cluster_a, cluster_b, dist_matrix):
    distances = []
    for i in cluster_a:
        for j in cluster_b:
            distances.append(dist_matrix[i, j])
    return np.mean(distances)

# %%
def hierarchical_clustering(X):
    n = X.shape[0]
    dist_matrix = compute_distance_matrix(X)
    
    # Start with each point as its own cluster
    clusters = [[i] for i in range(n)]
    linkage_history = []

    while len(clusters) > 1:
        min_dist = np.inf
        pair_to_merge = (0, 1)

        # Find closest pair of clusters
        for i in range(len(clusters)):
            for j in range(i + 1, len(clusters)):
                dist = average_linkage(clusters[i], clusters[j], dist_matrix)
                if dist < min_dist:
                    min_dist = dist
                    pair_to_merge = (i, j)

        i, j = pair_to_merge
        new_cluster = clusters[i] + clusters[j]

        # Save merge step (for dendrogram-like output)
        linkage_history.append((clusters[i], clusters[j], min_dist))

        # Update clusters
        clusters.pop(j)
        clusters.pop(i)
        clusters.append(new_cluster)

    return linkage_history

# %%
linkage_history = hierarchical_clustering(X)

# Display merge steps
for step, (c1, c2, dist) in enumerate(linkage_history, 1):
    print(f"Step {step}: Merge {c1} and {c2} at distance {dist:.4f}")
# Out:
# Step 1: Merge [25] and [64] at distance 49.6352
# Step 2: Merge [0] and [56] at distance 54.7063
# Step 3: Merge [146] and [147] at distance 55.5273
# Step 4: Merge [31] and [106] at distance 69.2352
# Step 5: Merge [164] and [165] at distance 72.2939
# Step 6: Merge [17] and [97] at distance 75.5184
# Step 7: Merge [50] and [93] at distance 80.7371
# Step 8: Merge [126] and [25, 64] at distance 82.1461
# Step 9: Merge [142] and [166] at distance 96.2613
# Step 10: Merge [28] and [40] at distance 100.4809
# Step 11: Merge [12] and [27] at distance 100.6157
# Step 12: Merge [69] and [164, 165] at distance 101.7339
# Step 13: Merge [115] and [128] at distance 101.7365
# Step 14: Merge [155] and [0, 56] at distance 105.0152
# Step 15: Merge [37] and [88] at distance 107.8945
# Step 16: Merge [132] and [150] at distance 119.3676
# Step 17: Merge [112] and [31, 106] at distance 128.4475
# Step 18: Merge [50, 93] and [126, 25, 64] at distance 132.2284
# Step 19: Merge [57] and [62] at distance 134.3230
# Step 20: Merge [26] and [37, 88] at distance 159.2761
# Step 21: Merge [109] and [146, 147] at distance 171.0335
# Step 22: Merge [94] and [112, 31, 106] at distance 173.7504
# Step 23: Merge [36] and [66] at distance 187.6864
# Step 24: Merge [32] and [17, 97] at distance 190.8363
# Step 25: Merge [20] and [34] at distance 198.9640
# Step 26: Merge [80] and [12, 27] at distance 202.3847
# Step 27: Merge [2] and [72] at distance 204.4748
# Step 28: Merge [63] and [132, 150] at distance 210.2699
# Step 29: Merge [81] and [136] at distance 212.2111
# Step 30: Merge [155, 0, 56] and [50, 93, 126, 25, 64] at distance 226.5124
# Step 31: Merge [161] and [69, 164, 165] at distance 231.2249
# Step 32: Merge [36, 66] and [155, 0, 56, 50, 93, 126, 25, 64] at distance 240.8402
# Step 33: Merge [48] and [118] at distance 241.9885
# Step 34: Merge [19] and [120] at distance 242.6796
# Step 35: Merge [3] and [30] at distance 252.4648
# Step 36: Merge [109, 146, 147] and [32, 17, 97] at distance 261.8746
# Step 37: Merge [26, 37, 88] and [94, 112, 31, 106] at distance 269.0287
# Step 38: Merge [87] and [129] at distance 272.4397
# Step 39: Merge [99] and [142, 166] at distance 278.1589
# Step 40: Merge [9] and [14] at distance 281.3684
# Step 41: Merge [46] and [20, 34] at distance 290.3808
# Step 42: Merge [105] and [57, 62] at distance 294.3857
# Step 43: Merge [59] and [99, 142, 166] at distance 302.1829
# Step 44: Merge [84] and [107] at distance 307.5812
# Step 45: Merge [63, 132, 150] and [36, 66, 155, 0, 56, 50, 93, 126, 25, 64] at distance 310.9265
# Step 46: Merge [70] and [140] at distance 327.8850
# Step 47: Merge [83] and [80, 12, 27] at distance 331.2420
# Step 48: Merge [103] and [156] at distance 339.7511
# Step 49: Merge [116] and [161, 69, 164, 165] at distance 345.8909
# Step 50: Merge [1] and [154] at distance 356.5192
# Step 51: Merge [16] and [76] at distance 361.7665
# Step 52: Merge [6] and [105, 57, 62] at distance 374.0455
# Step 53: Merge [65] and [3, 30] at distance 386.9181
# Step 54: Merge [101] and [162] at distance 407.1123
# Step 55: Merge [87, 129] and [83, 80, 12, 27] at distance 409.8812
# Step 56: Merge [38] and [113] at distance 431.2598
# Step 57: Merge [127] and [151] at distance 432.1422
# Step 58: Merge [28, 40] and [87, 129, 83, 80, 12, 27] at distance 455.9249
# Step 59: Merge [100] and [117] at distance 507.0114
# Step 60: Merge [152] and [1, 154] at distance 512.5138
# Step 61: Merge [52] and [48, 118] at distance 543.7369
# Step 62: Merge [102] and [84, 107] at distance 588.3724
# Step 63: Merge [116, 161, 69, 164, 165] and [102, 84, 107] at distance 594.1093
# Step 64: Merge [119] and [46, 20, 34] at distance 604.7436
# Step 65: Merge [109, 146, 147, 32, 17, 97] and [63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64] at distance 605.1711
# Step 66: Merge [19, 120] and [38, 113] at distance 624.5287
# Step 67: Merge [85] and [153] at distance 672.4601
# Step 68: Merge [103, 156] and [52, 48, 118] at distance 708.9072
# Step 69: Merge [67] and [121] at distance 709.1742
# Step 70: Merge [65, 3, 30] and [127, 151] at distance 730.8478
# Step 71: Merge [152, 1, 154] and [119, 46, 20, 34] at distance 734.3048
# Step 72: Merge [61] and [96] at distance 752.4031
# Step 73: Merge [4] and [33] at distance 762.1632
# Step 74: Merge [21] and [104] at distance 775.6236
# Step 75: Merge [55] and [100, 117] at distance 789.2315
# Step 76: Merge [26, 37, 88, 94, 112, 31, 106] and [109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64] at distance 817.4960
# Step 77: Merge [18] and [6, 105, 57, 62] at distance 820.4316
# Step 78: Merge [35] and [45] at distance 824.9522
# Step 79: Merge [59, 99, 142, 166] and [28, 40, 87, 129, 83, 80, 12, 27] at distance 848.1060
# Step 80: Merge [108] and [16, 76] at distance 859.1011
# Step 81: Merge [130] and [148] at distance 866.1986
# Step 82: Merge [2, 72] and [130, 148] at distance 933.7812
# Step 83: Merge [5] and [85, 153] at distance 942.4856
# Step 84: Merge [78] and [152, 1, 154, 119, 46, 20, 34] at distance 973.2668
# Step 85: Merge [81, 136] and [26, 37, 88, 94, 112, 31, 106, 109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64] at distance 996.2550
# Step 86: Merge [79] and [95] at distance 1001.9413
# Step 87: Merge [86] and [55, 100, 117] at distance 1016.6856
# Step 88: Merge [103, 156, 52, 48, 118] and [18, 6, 105, 57, 62] at distance 1041.9976
# Step 89: Merge [137] and [61, 96] at distance 1159.6395
# Step 90: Merge [141] and [35, 45] at distance 1197.9240
# Step 91: Merge [19, 120, 38, 113] and [65, 3, 30, 127, 151] at distance 1199.0353
# Step 92: Merge [39] and [143] at distance 1204.4489
# Step 93: Merge [24] and [9, 14] at distance 1216.2384
# Step 94: Merge [90] and [67, 121] at distance 1275.3202
# Step 95: Merge [41] and [4, 33] at distance 1281.1541
# Step 96: Merge [43] and [98] at distance 1306.1079
# Step 97: Merge [42] and [139] at distance 1404.1278
# Step 98: Merge [47] and [70, 140] at distance 1417.6464
# Step 99: Merge [149] and [101, 162] at distance 1467.1564
# Step 100: Merge [116, 161, 69, 164, 165, 102, 84, 107] and [59, 99, 142, 166, 28, 40, 87, 129, 83, 80, 12, 27] at distance 1468.2655
# Step 101: Merge [29] and [53] at distance 1500.0518
# Step 102: Merge [7] and [144] at distance 1513.6365
# Step 103: Merge [137, 61, 96] and [141, 35, 45] at distance 1602.3401
# Step 104: Merge [58] and [68] at distance 1603.1836
# Step 105: Merge [73] and [110] at distance 1612.9202
# Step 106: Merge [92] and [2, 72, 130, 148] at distance 1634.1395
# Step 107: Merge [71] and [24, 9, 14] at distance 1661.8730
# Step 108: Merge [160] and [5, 85, 153] at distance 1701.7146
# Step 109: Merge [103, 156, 52, 48, 118, 18, 6, 105, 57, 62] and [19, 120, 38, 113, 65, 3, 30, 127, 151] at distance 1725.4314
# Step 110: Merge [122] and [135] at distance 1749.8118
# Step 111: Merge [108, 16, 76] and [78, 152, 1, 154, 119, 46, 20, 34] at distance 1796.0158
# Step 112: Merge [131] and [79, 95] at distance 1812.5585
# Step 113: Merge [54] and [158] at distance 1838.4828
# Step 114: Merge [21, 104] and [39, 143] at distance 1868.8005
# Step 115: Merge [47, 70, 140] and [108, 16, 76, 78, 152, 1, 154, 119, 46, 20, 34] at distance 1990.3760
# Step 116: Merge [81, 136, 26, 37, 88, 94, 112, 31, 106, 109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64] and [116, 161, 69, 164, 165, 102, 84, 107, 59, 99, 142, 166, 28, 40, 87, 129, 83, 80, 12, 27] at distance 2043.9791
# Step 117: Merge [124] and [86, 55, 100, 117] at distance 2100.7568
# Step 118: Merge [51] and [90, 67, 121] at distance 2266.3178
# Step 119: Merge [71, 24, 9, 14] and [124, 86, 55, 100, 117] at distance 2379.3633
# Step 120: Merge [41, 4, 33] and [160, 5, 85, 153] at distance 2501.3504
# Step 121: Merge [15] and [29, 53] at distance 2624.1155
# Step 122: Merge [149, 101, 162] and [81, 136, 26, 37, 88, 94, 112, 31, 106, 109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64, 116, 161, 69, 164, 165, 102, 84, 107, 59, 99, 142, 166, 28, 40, 87, 129, 83, 80, 12, 27] at distance 2663.0055
# Step 123: Merge [43, 98] and [122, 135] at distance 2666.1186
# Step 124: Merge [137, 61, 96, 141, 35, 45] and [92, 2, 72, 130, 148] at distance 2696.6562
# Step 125: Merge [138] and [43, 98, 122, 135] at distance 2702.6287
# Step 126: Merge [13] and [163] at distance 2773.6596
# Step 127: Merge [125] and [51, 90, 67, 121] at distance 2785.1331
# Step 128: Merge [21, 104, 39, 143] and [71, 24, 9, 14, 124, 86, 55, 100, 117] at distance 2928.3054
# Step 129: Merge [8] and [15, 29, 53] at distance 3095.3958
# Step 130: Merge [111] and [42, 139] at distance 3159.4809
# Step 131: Merge [131, 79, 95] and [41, 4, 33, 160, 5, 85, 153] at distance 3191.9079
# Step 132: Merge [47, 70, 140, 108, 16, 76, 78, 152, 1, 154, 119, 46, 20, 34] and [137, 61, 96, 141, 35, 45, 92, 2, 72, 130, 148] at distance 3334.9443
# Step 133: Merge [58, 68] and [54, 158] at distance 3769.0903
# Step 134: Merge [74] and [111, 42, 139] at distance 3772.4877
# Step 135: Merge [125, 51, 90, 67, 121] and [131, 79, 95, 41, 4, 33, 160, 5, 85, 153] at distance 3839.9405
# Step 136: Merge [22] and [13, 163] at distance 3957.3444
# Step 137: Merge [159] and [73, 110] at distance 4026.4082
# Step 138: Merge [11] and [115, 128] at distance 4474.7369
# Step 139: Merge [103, 156, 52, 48, 118, 18, 6, 105, 57, 62, 19, 120, 38, 113, 65, 3, 30, 127, 151] and [149, 101, 162, 81, 136, 26, 37, 88, 94, 112, 31, 106, 109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64, 116, 161, 69, 164, 165, 102, 84, 107, 59, 99, 142, 166, 28, 40, 87, 129, 83, 80, 12, 27] at distance 4585.2093
# Step 140: Merge [77] and [58, 68, 54, 158] at distance 4742.6714
# Step 141: Merge [60] and [138, 43, 98, 122, 135] at distance 5233.8696
# Step 142: Merge [7, 144] and [159, 73, 110] at distance 5590.3205
# Step 143: Merge [125, 51, 90, 67, 121, 131, 79, 95, 41, 4, 33, 160, 5, 85, 153] and [22, 13, 163] at distance 5741.6520
# Step 144: Merge [21, 104, 39, 143, 71, 24, 9, 14, 124, 86, 55, 100, 117] and [47, 70, 140, 108, 16, 76, 78, 152, 1, 154, 119, 46, 20, 34, 137, 61, 96, 141, 35, 45, 92, 2, 72, 130, 148] at distance 5927.0272
# Step 145: Merge [75] and [77, 58, 68, 54, 158] at distance 6123.0034
# Step 146: Merge [23] and [82] at distance 6276.9451
# Step 147: Merge [89] and [134] at distance 6293.7824
# Step 148: Merge [8, 15, 29, 53] and [7, 144, 159, 73, 110] at distance 6375.6762
# Step 149: Merge [49] and [89, 134] at distance 7491.1197
# Step 150: Merge [10] and [60, 138, 43, 98, 122, 135] at distance 8068.6614
# Step 151: Merge [49, 89, 134] and [10, 60, 138, 43, 98, 122, 135] at distance 9357.0354
# Step 152: Merge [103, 156, 52, 48, 118, 18, 6, 105, 57, 62, 19, 120, 38, 113, 65, 3, 30, 127, 151, 149, 101, 162, 81, 136, 26, 37, 88, 94, 112, 31, 106, 109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64, 116, 161, 69, 164, 165, 102, 84, 107, 59, 99, 142, 166, 28, 40, 87, 129, 83, 80, 12, 27] and [21, 104, 39, 143, 71, 24, 9, 14, 124, 86, 55, 100, 117, 47, 70, 140, 108, 16, 76, 78, 152, 1, 154, 119, 46, 20, 34, 137, 61, 96, 141, 35, 45, 92, 2, 72, 130, 148] at distance 9784.8610
# Step 153: Merge [44] and [8, 15, 29, 53, 7, 144, 159, 73, 110] at distance 9956.4635
# Step 154: Merge [74, 111, 42, 139] and [75, 77, 58, 68, 54, 158] at distance 10789.2242
# Step 155: Merge [133] and [23, 82] at distance 11408.2873
# Step 156: Merge [125, 51, 90, 67, 121, 131, 79, 95, 41, 4, 33, 160, 5, 85, 153, 22, 13, 163] and [49, 89, 134, 10, 60, 138, 43, 98, 122, 135] at distance 13591.2442
# Step 157: Merge [114] and [145] at distance 14848.6109
# Step 158: Merge [44, 8, 15, 29, 53, 7, 144, 159, 73, 110] and [74, 111, 42, 139, 75, 77, 58, 68, 54, 158] at distance 15273.2748
# Step 159: Merge [157] and [133, 23, 82] at distance 19838.8186
# Step 160: Merge [103, 156, 52, 48, 118, 18, 6, 105, 57, 62, 19, 120, 38, 113, 65, 3, 30, 127, 151, 149, 101, 162, 81, 136, 26, 37, 88, 94, 112, 31, 106, 109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64, 116, 161, 69, 164, 165, 102, 84, 107, 59, 99, 142, 166, 28, 40, 87, 129, 83, 80, 12, 27, 21, 104, 39, 143, 71, 24, 9, 14, 124, 86, 55, 100, 117, 47, 70, 140, 108, 16, 76, 78, 152, 1, 154, 119, 46, 20, 34, 137, 61, 96, 141, 35, 45, 92, 2, 72, 130, 148] and [125, 51, 90, 67, 121, 131, 79, 95, 41, 4, 33, 160, 5, 85, 153, 22, 13, 163, 49, 89, 134, 10, 60, 138, 43, 98, 122, 135] at distance 20582.4754
# Step 161: Merge [11, 115, 128] and [44, 8, 15, 29, 53, 7, 144, 159, 73, 110, 74, 111, 42, 139, 75, 77, 58, 68, 54, 158] at distance 24880.2047
# Step 162: Merge [157, 133, 23, 82] and [11, 115, 128, 44, 8, 15, 29, 53, 7, 144, 159, 73, 110, 74, 111, 42, 139, 75, 77, 58, 68, 54, 158] at distance 33861.2810
# Step 163: Merge [91] and [114, 145] at distance 40666.9682
# Step 164: Merge [103, 156, 52, 48, 118, 18, 6, 105, 57, 62, 19, 120, 38, 113, 65, 3, 30, 127, 151, 149, 101, 162, 81, 136, 26, 37, 88, 94, 112, 31, 106, 109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64, 116, 161, 69, 164, 165, 102, 84, 107, 59, 99, 142, 166, 28, 40, 87, 129, 83, 80, 12, 27, 21, 104, 39, 143, 71, 24, 9, 14, 124, 86, 55, 100, 117, 47, 70, 140, 108, 16, 76, 78, 152, 1, 154, 119, 46, 20, 34, 137, 61, 96, 141, 35, 45, 92, 2, 72, 130, 148, 125, 51, 90, 67, 121, 131, 79, 95, 41, 4, 33, 160, 5, 85, 153, 22, 13, 163, 49, 89, 134, 10, 60, 138, 43, 98, 122, 135] and [157, 133, 23, 82, 11, 115, 128, 44, 8, 15, 29, 53, 7, 144, 159, 73, 110, 74, 111, 42, 139, 75, 77, 58, 68, 54, 158] at distance 50194.1763
# Step 165: Merge [123] and [91, 114, 145] at distance 60941.0086
# Step 166: Merge [103, 156, 52, 48, 118, 18, 6, 105, 57, 62, 19, 120, 38, 113, 65, 3, 30, 127, 151, 149, 101, 162, 81, 136, 26, 37, 88, 94, 112, 31, 106, 109, 146, 147, 32, 17, 97, 63, 132, 150, 36, 66, 155, 0, 56, 50, 93, 126, 25, 64, 116, 161, 69, 164, 165, 102, 84, 107, 59, 99, 142, 166, 28, 40, 87, 129, 83, 80, 12, 27, 21, 104, 39, 143, 71, 24, 9, 14, 124, 86, 55, 100, 117, 47, 70, 140, 108, 16, 76, 78, 152, 1, 154, 119, 46, 20, 34, 137, 61, 96, 141, 35, 45, 92, 2, 72, 130, 148, 125, 51, 90, 67, 121, 131, 79, 95, 41, 4, 33, 160, 5, 85, 153, 22, 13, 163, 49, 89, 134, 10, 60, 138, 43, 98, 122, 135, 157, 133, 23, 82, 11, 115, 128, 44, 8, 15, 29, 53, 7, 144, 159, 73, 110, 74, 111, 42, 139, 75, 77, 58, 68, 54, 158] and [123, 91, 114, 145] at distance 102890.5115

# %%
def silhouette(X, labels):
    n = len(X)
    unique_clusters = np.unique(labels)
    silhouette_vals = []

    for i in range(n):
        same_cluster = labels == labels[i]
        other_clusters = labels != labels[i]

        # a = intra-cluster distance
        if np.sum(same_cluster) > 1:
            a = np.mean([np.linalg.norm(X[i] - X[j])
                         for j in range(n) if same_cluster[j] and j != i])
        else:
            a = 0

        # b = nearest-cluster distance
        b = np.inf
        for cluster in unique_clusters:
            if cluster != labels[i]:
                cluster_points = X[labels == cluster]
                dist = np.mean([np.linalg.norm(X[i] - p) for p in cluster_points])
                b = min(b, dist)

        s = (b - a) / max(a, b)
        silhouette_vals.append(s)

    return np.mean(silhouette_vals)

# %%
def get_hierarchical_labels(X, k):
    n = X.shape[0]
    dist_matrix = compute_distance_matrix(X)

    # Start with each point as its own cluster
    clusters = [[i] for i in range(n)]

    while len(clusters) > k:
        min_dist = np.inf
        pair_to_merge = (0, 1)

        for i in range(len(clusters)):
            for j in range(i + 1, len(clusters)):
                dist = average_linkage(clusters[i], clusters[j], dist_matrix)
                if dist < min_dist:
                    min_dist = dist
                    pair_to_merge = (i, j)

        i, j = pair_to_merge
        new_cluster = clusters[i] + clusters[j]

        clusters.pop(j)
        clusters.pop(i)
        clusters.append(new_cluster)

    # Create labels array
    labels = np.zeros(n, dtype=int)
    for cluster_id, cluster in enumerate(clusters):
        for idx in cluster:
            labels[idx] = cluster_id

    return labels

# %%
k = 3  # choose number of clusters
labels = get_hierarchical_labels(X, k)

# %%
print("Silhouette Score:", silhouette(X, labels))
# Out:
# Silhouette Score: 0.7160188906800354
